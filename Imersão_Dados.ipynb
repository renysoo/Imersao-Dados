# %% [markdown]
# <a href="https://colab.research.google.com/github/renysoo/Imersao-Dados/blob/master/Imers%C3%A3o_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dia 1

# %% [markdown]
# ##Importação dos dados e pacote

# %%
import pandas as pd

urlDados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(urlDados, compression= 'zip')

dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['dose'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# *italicized text*##Desafio 1: Investigar por que a classe de tratamentos é tão desbalanceada.

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dadosComControle = dados[dados['tratamento'] == 'com_controle']

# %%
dadosComControle = dados[dados['tratamento'] == 'com_controle']
dadosComControle['droga'].unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %% [markdown]
# Como no caso com controle só foi usado uma variação do tipo 'droga' existe uma grande diferença no número de experimetos conduzidos, pois a variação ocorreu somente no tempo e dose.

# %% [markdown]
# ##Desafio 2: Plotar as 5 ultimas linhas da tabela.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafio 3: Proporção das classes tratamento

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# ##Desafio 4: Quantos tipos de drogas foram investigadas?

# %%
dados['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# ##Desafio 05: Procurar na documentação o método query(pandas).

# %%
# dados.query('g-0 > 0')

# %% [markdown]
# ##Desafio 06: Renomear as colunas tirando o hífen.

# %%
dados.columns = dados.columns.str.replace('-','')

# %%
dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# ##Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
dados['tratamento'].value_counts().plot.pie(labels=['Com droga','Com controle'],labeldistance=1.5,colors=['red','blue'],shadow=True)

# %%
dados['tempo'].value_counts().plot.bar(color='violet', edgecolor = 'gray')

# %% [markdown]
# ##Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Com o estudo dos dados coletados podemos identificar que foram realizados experimentos com diferentes drogas em um tipo de colonia de células.
# Para atestar o resultado real de cada droga foram realizados experimentos sem drogas porém nas mesmas condições de experimento.
# Duas tipos de doses foram aplicadas em proporções equilibradas e durantes 3 periódos de tempo também em proporções similares.

# %% [markdown]
# #Dia 2

# %% [markdown]
# Alterar nome droga para composto

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace= True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Adicionar a biblioteca Seaborn para plotar gráficos

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
plt.figure(figsize=(8,6))
dados['g0'].hist(bins=100)

# %%
plt.figure(figsize=(8,6))
dados['g6'].hist(bins=100)

# %% [markdown]
# ##Desafio 01: Ordenar o gráfico countplot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))

dadosRelevantes = dados.query('composto in @cod_compostos')

ax = sns.countplot(x = 'composto', data = dadosRelevantes, order=dadosRelevantes['composto'].value_counts().index)
ax.set_title('Top 5 compostos')
plt.show()

# %% [markdown]
# ##Desafio 02: Melhorar a visualização alterando tamanho da fonte...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))

dadosRelevantes = dados.query('composto in @cod_compostos')

ax = sns.countplot(x = 'composto', data = dadosRelevantes, order=dadosRelevantes['composto'].value_counts().index, palette='Set3')
ax.set_title('Top 5 compostos',fontweight='bold', fontsize=20)
ax.set_xlabel('Composto',fontsize=15, labelpad=10)
ax.set_ylabel('Contagem', fontsize=15, labelpad=10)
for patch in ax.patches:
  ax.annotate(patch.get_height(), (patch.get_x()+0.25, patch.get_height()))
plt.show()

# %% [markdown]
# ##Desafio 03: Plotar os histogramas com seaborn

# %%
plt.figure(figsize=(8,6))
dadosHist = dados
ax = sns.histplot(x='g0',data=dadosHist,kde=True)
ax.set_title('Resultados g0',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)
plt.show()

# %% [markdown]
# ##Desafio 04: Estudar sobre as estatísticas retornadas no .describe()

# %%
dados.loc[:,'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
plt.figure(figsize=(6,3))
dadosHist = dados.loc[:,'g0':'g771'].describe().T
ax = sns.histplot(x='mean',data=dadosHist)
ax.set_title('Média',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)

plt.figure(figsize=(6,3))
dadosHist = dados.loc[:,'g0':'g771'].describe().T
ax = sns.histplot(x='std',data=dadosHist)
ax.set_title('Desvio padrão',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)

plt.figure(figsize=(6,3))
dadosHist = dados.loc[:,'g0':'g771'].describe().T
ax = sns.histplot(x='min',data=dadosHist)
ax.set_title('Valor mínimo',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)

plt.figure(figsize=(6,3))
dadosHist = dados.loc[:,'g0':'g771'].describe().T
ax = sns.histplot(x='max',data=dadosHist)
ax.set_title('Valor máximo',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)

plt.figure(figsize=(6,3))
dadosHist = dados.loc[:,'g0':'g771'].describe().T
ax = sns.histplot(x='50%',data=dadosHist)
ax.set_title('Mediana',fontsize=20,fontweight='bold')
ax.set_xlabel('valores',fontsize=10, labelpad=10)
ax.set_ylabel('quantidade',fontsize=10, labelpad=10)

plt.show()

# %% [markdown]
# ##Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# ##Desafio 06: Fazer outras análises com o boxplot e até com o histograma.

# %% [markdown]
# ##Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# #Dia 3

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0','g3']]
sns.scatterplot(x='g0',y='g8', data=dados)

# %%
sns.lmplot(data=dados,x='g0',y='g8', line_kws={'color':'red'}, col='tratamento',row='tempo')

# %%
dados.loc[:,'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:,'g0':'g50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11,9))

cmap = sns.diverging_palette(230,20, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={'shrink':.5})

# %%
corrCelulas = dados.loc[:,'c0':'c50'].corr()
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11,9))

cmap = sns.diverging_palette(230,20, as_cmap=True)
sns.heatmap(corrCelulas, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={'shrink':.5})

# %% [markdown]
# ##Desafio 1: Criar tabelas de frequência com pandas.groupby()

# %%
pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
dados.groupby(['dose','tempo']).size()
# Out:
# dose  tempo
# D1    24       3886
#       48       4354
#       72       3907
# D2    24       3886
#       48       3896
#       72       3885
# dtype: int64

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
dados.groupby(['dose','tempo',])['tratamento'].value_counts(normalize=True)
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       0.922542
#              com_controle    0.077458
#       48     com_droga       0.921222
#              com_controle    0.078778
#       72     com_droga       0.921423
#              com_controle    0.078577
# D2    24     com_droga       0.921513
#              com_controle    0.078487
#       48     com_droga       0.921715
#              com_controle    0.078285
#       72     com_droga       0.921493
#              com_controle    0.078507
# Name: tratamento, dtype: float64

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados.groupby(['dose','tempo','tratamento']).mean()
# Out:
#                                g0        g1  ...       c98       c99
# dose tempo tratamento                        ...
# D1   24    com_controle -0.251760 -0.453322  ...  0.350566  0.342308
#            com_droga     0.367996 -0.170839  ... -0.340809 -0.216371
#      48    com_controle -0.122773 -0.453638  ...  0.408657  0.450673
#            com_droga     0.412469 -0.142581  ... -0.634006 -0.389838
#      72    com_controle -0.295271 -0.669059  ...  0.379652  0.319684
#            com_droga     0.286250 -0.127878  ... -0.835132 -0.588545
# D2   24    com_controle  0.010754 -0.229451  ...  0.134107  0.112021
#            com_droga     0.115253 -0.081764  ... -0.254499 -0.187848
#      48    com_controle  0.013174  0.001737  ...  0.232461  0.169539
#            com_droga     0.214480 -0.001143  ... -0.485368 -0.317882
#      72    com_controle  0.070250  0.133537  ...  0.200942  0.165440
#            com_droga     0.253439  0.052840  ... -0.644784 -0.391018
#
# ...

# %% [markdown]
# ##Desafio 02: Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# ##Desafio 03: Explorar outros agregadores.

# %% [markdown]
# ##Desafio 04: Explorar o melt.

# %% [markdown]
# ##Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.

# %% [markdown]
# ##Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)

# %% [markdown]
# ##Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# #Dia 4

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.drop('id',axis=1).select_dtypes('int64').sum().sort_values(ascending=False)
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id',axis=1).sum(axis=1)
dados_resultados['ativo_moa'] = (dados_resultados.drop('id',axis=1).sum(axis=1) != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id','n_moa','ativo_moa']],on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
compostos_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @compostos_principal'), y='g0', x='composto', hue='ativo_moa')

# %% [markdown]
# ##Desafio 01: Encontrar o top 10, das ações do MOA (inibidor, agonista...)

# %%
dados_resultados.drop('id',axis=1).select_dtypes('int64').sum().sort_values(ascending=False)[1:11]
# Out:
# nfkb_inhibitor                    832
# proteasome_inhibitor              726
# cyclooxygenase_inhibitor          435
# dopamine_receptor_antagonist      424
# serotonin_receptor_antagonist     404
# dna_inhibitor                     402
# glutamate_receptor_antagonist     367
# adrenergic_receptor_antagonist    360
# cdk_inhibitor                     340
# egfr_inhibitor                    336
# dtype: int64

# %%
dados_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False).reset_index()[2:]
dados_moa.columns = ['MOA', 'quantidade']
dados_moa
# Out:
#                                             MOA  quantidade
# 2                                nfkb_inhibitor         832
# 3                          proteasome_inhibitor         726
# 4                      cyclooxygenase_inhibitor         435
# 5                  dopamine_receptor_antagonist         424
# 6                 serotonin_receptor_antagonist         404
# ..                                          ...         ...
# 203                                     steroid           6
# 204                  nicotinic_receptor_agonist           6
# 205                          elastase_inhibitor           6
# 206                             erbb2_inhibitor           1
# 207  atp-sensitive_potassium_channel_antagonist           1
#
# [206 rows x 2 columns]

# %%
list_acao = []

moa_split = dados_moa['MOA'].str.split('_')
for row in moa_split:
    list_acao.append(row[-1])
list_acao[:5]
# Out:
# ['inhibitor', 'inhibitor', 'inhibitor', 'antagonist', 'antagonist']

# %%
dados_moa['acao'] = list_acao
dados_moa
# Out:
#                                             MOA  quantidade        acao
# 2                                nfkb_inhibitor         832   inhibitor
# 3                          proteasome_inhibitor         726   inhibitor
# 4                      cyclooxygenase_inhibitor         435   inhibitor
# 5                  dopamine_receptor_antagonist         424  antagonist
# 6                 serotonin_receptor_antagonist         404  antagonist
# ..                                          ...         ...         ...
# 203                                     steroid           6     steroid
# 204                  nicotinic_receptor_agonist           6     agonist
# 205                          elastase_inhibitor           6   inhibitor
# 206                             erbb2_inhibitor           1   inhibitor
# 207  atp-sensitive_potassium_channel_antagonist           1  antagonist
#
# [206 rows x 3 columns]

# %%
top10_acoes = dados_moa.groupby('acao').agg({'quantidade':'sum'}).sort_values('quantidade', ascending=False).head(10)
top10_acoes = top10_acoes.reset_index()
top10_acoes
# Out:
#                 acao  quantidade
# 0          inhibitor        9693
# 1         antagonist        3449
# 2            agonist        2330
# 3            blocker         323
# 4              agent         150
# 5          activator         115
# 6              local          80
# 7        antioxidant          73
# 8  anti-inflammatory          73
# 9  immunosuppressant          73

# %% [markdown]
# ##Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True        False
# 1      id_000779bfc     com_droga     72  ...     0     False        False
# 2      id_000a6266a     com_droga     48  ...     3      True        False
# 3      id_0015fd391     com_droga     48  ...     0     False        False
# 4      id_001626bd3     com_droga     72  ...     1      True        False
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True        False
# 23810  id_fffb70c0c     com_droga     24  ...     1      True        False
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False         True
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True        False
# 23813  id_ffffdd77b     com_droga     72  ...     0     False        False
#
# [23814 rows x 880 columns]

# %% [markdown]
# ##Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72

# %%
dados_combinados['24h'] = (dados_combinados['tempo'] == 24)
dados_combinados['48h'] = (dados_combinados['tempo'] == 48)
dados_combinados['72'] = (dados_combinados['tempo'] == 72)
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle    24h    48h     72
# 0      id_000644bb2     com_droga     24   D1  ...       False   True  False  False
# 1      id_000779bfc     com_droga     72   D1  ...       False  False  False   True
# 2      id_000a6266a     com_droga     48   D1  ...       False  False   True  False
# 3      id_0015fd391     com_droga     48   D1  ...       False  False   True  False
# 4      id_001626bd3     com_droga     72   D2  ...       False  False  False   True
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   True  False  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   True  False  False
# ...

# %% [markdown]
# ##Desafio 04: Estudar sobre combinações de DF https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ##Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)

# %%
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle    24h    48h     72
# 0      id_000644bb2     com_droga     24   D1  ...       False   True  False  False
# 1      id_000779bfc     com_droga     72   D1  ...       False  False  False   True
# 2      id_000a6266a     com_droga     48   D1  ...       False  False   True  False
# 3      id_0015fd391     com_droga     48   D1  ...       False  False   True  False
# 4      id_001626bd3     com_droga     72   D2  ...       False  False  False   True
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   True  False  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   True  False  False
# ...

# %%
compostos_analizados = dados_combinados['composto'].value_counts().index[:2]
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @compostos_analizados'), y='g0', x='composto', hue='ativo_moa')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @compostos_analizados'), y='g0', x='composto', hue='dose')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=dados_combinados.query('composto in @compostos_analizados'), y='g0', x='composto', hue='tempo')

# %% [markdown]
# ##Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
dados_combinados
# Out:
#                  id    tratamento  tempo dose  ... eh_controle    24h    48h     72
# 0      id_000644bb2     com_droga     24   D1  ...       False   True  False  False
# 1      id_000779bfc     com_droga     72   D1  ...       False  False  False   True
# 2      id_000a6266a     com_droga     48   D1  ...       False  False   True  False
# 3      id_0015fd391     com_droga     48   D1  ...       False  False   True  False
# 4      id_001626bd3     com_droga     72   D2  ...       False  False  False   True
# ...             ...           ...    ...  ...  ...         ...    ...    ...    ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...       False   True  False  False
# 23810  id_fffb70c0c     com_droga     24   D2  ...       False   True  False  False
# 23811  id_fffc1c3f4  com_controle     48   D2  ...        True  False   True  False
# 23812  id_fffcb9e7c     com_droga     24   D1  ...       False   True  False  False
# ...

# %%
lista_compostos = dados_combinados['composto'].value_counts()

# %% [markdown]
# ##Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes

# %% [markdown]
# ##Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# #Dia 5

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle    24h    48h     72
# 0  id_000644bb2  com_droga     24   D1  ...       False   True  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False   True
# 2  id_000a6266a  com_droga     48   D1  ...       False  False   True  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False   True  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False   True
#
# [5 rows x 883 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, stratify=y, test_size = 0.2, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino,y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste,previsao_dummy)
# Out:
# 0.6067604450976275

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, stratify=y, test_size = 0.2, random_state=376)

teste = []
treino = []

for i in range(1,15):
  modelo_arvore = DecisionTreeClassifier(max_depth=i)
  modelo_arvore.fit(x_treino,y_treino)
  teste.append(modelo_arvore.score(x_teste,y_teste))
  treino.append(modelo_arvore.score(x_treino,y_treino))

# %%
sns.lineplot(x=range(1,15), y = teste, label='teste')
sns.lineplot(x=range(1,15), y = treino, label='treino')

# %%
pd.get_dummies(dados_combinados, columns=['tratamento','dose','tempo'])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id','n_moa','ativo_moa','composto','eh_controle','24h','48h','72'], axis=1)
y = dados_combinados['ativo_moa']

x = pd.get_dummies(x, columns=['tratamento','dose','tempo'])

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, stratify=y, test_size = 0.2, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino,y_treino)
modelo_randomforest.score(x_teste,y_teste)
# Out:
# 0.6812933025404158
